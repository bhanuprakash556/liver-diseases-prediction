# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df =pd.read_csv("heart.csv")
df.head()
df1=df

# %%
print(sns.countplot(x="sex",hue="target",data=df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.countplot(x="cp",hue="target",data=df)

# %%
print(sns.countplot(x="fbs",hue="target",data=df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.countplot(x="restecg",hue="target",data=df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.countplot(x="exang",hue="target",data=df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.countplot(x="slope",hue="target",data=df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.countplot(x="thal",hue="target",data=df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.countplot(x="ca",hue="target",data=df))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df.dtypes
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (303, 14)

# %%
df2=pd.get_dummies(df,columns=["sex","cp","fbs","restecg","exang","slope","ca","thal"])
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
df2.shape
# Out:
# (303, 31)

# %%
#from sklearn.svm import SVC
#classifier = SVC(kernel = 'rbf')
#classifier.fit(x_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#print(classifier.score(x_train,y_train),":"
#,classifier.score(x_test,y_test))
# Out:
# 1.0 : 0.5384615384615384

# %%
x =df1[['age',"sex",'trestbps','chol','cp']]
y = df1["target"]

# %%
x.shape,y.shape
# Out:
# ((303, 5), (303,))

# %%
## support vector machine

# %%
from sklearn.svm import SVC
sup = SVC(kernel = 'linear',C=3)
sup.fit(x_train, y_train)
s.score(x_train,y_train),":",s.score(x_test,y_test)
# Out:
# (0.8066037735849056, ':', 0.7252747252747253)

# %%
### logestic regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
logreg =LogisticRegression(class_weight='balanced')
s=logreg.fit(x_train,y_train)
s.score(x_train,y_train)
# Out:
# 0.7641509433962265

# %%
s.score(x_train,y_train),":",s.score(x_test,y_test)
# Out:
# (0.7641509433962265, ':', 0.7142857142857143)

# %%
a = np.array([63,1,3,145,233])
b=a.reshape(1,5)

df = pd.DataFrame(b)
df.shape
# Out:
# (1, 5)

# %%
s.predict(df)
# Out:
# array([1], dtype=int64)

# %%
import pickle
pickle.dump(s,open('heart1.pk','wb'))
